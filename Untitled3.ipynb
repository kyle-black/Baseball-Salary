# %%
import requests
import json

# %%
season = 2022
team = "HOU"

# %%
url = f"https://api.sportsdata.io/v3/mlb/stats/json/TeamSeasonStats/{season}"

# %%
url
# Out:
# 'https://api.sportsdata.io/v3/mlb/stats/json/TeamSeasonStats/2022'

# %%
key = '86f7221290a5431aaf2e968b66de003c'

# %%
headers = {'Ocp-Apim-Subscription-Key':f'{key}'}

# %%
r =requests.get(url, headers = headers)

# %%
r=r.text

# %%
y= json.loads(r)

# %%
y
# Out:
# [{'StatID': 3522218,
#   'TeamID': 14,
#   'SeasonType': 1,
#   'Season': 2022,
#   'Name': 'Arizona Diamondbacks',
#   'Team': 'ARI',
#   'GlobalTeamID': 10000014,
#   'Updated': '2022-12-11T04:03:26',
#   'Games': 168,
#   'FantasyPoints': 0.0,
#   'AtBats': 3553.1,
#   'Runs': 466.1,
#   'Hits': 818.7,
#   'Singles': 513.3,
#   'Doubles': 174.6,
#   'Triples': 15.9,
#   'HomeRuns': 114.9,
#   'RunsBattedIn': 436.9,
#   'BattingAverage': 0.1,
#   'Outs': 2734.4,
#   'Strikeouts': 890.4,
#   'Walks': 352.6,
#   'HitByPitch': 39.8,
#   'Sacrifices': 53.8,
#   'SacrificeFlies': 33.2,
#   'GroundIntoDoublePlay': 63.1,
#   'StolenBases': 69.1,
#   'CaughtStealing': 19.3,
#   'PitchesSeen': 15661.8,
#   'OnBasePercentage': 0.1,
#   'SluggingPercentage': 0.2,
#   'OnBasePlusSlugging': 0.3,
#   'Errors': 57.1,
#   'Wins': 49.1,
#   'Losses': 58.4,
#   'Saves': 21.9,
#   'InningsPitchedDecimal': 949.5,
#   'TotalOutsPitched': 2848.6,
#   'InningsPitchedFull': 949.5,
# ...
